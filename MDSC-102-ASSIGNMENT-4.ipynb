# %% [markdown]
# <a href="https://colab.research.google.com/github/charan-debug/MDSC-102-Infrential-Statistics/blob/main/MDSC-102-ASSIGNMENT-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ANALYSING WINE DATASET USING SCATTERPLOT**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine.data' ,names = name)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
sns.countplot(x = "Alcohol" , data = df)
plt.xlabel("Alcohol Types")  # Label for the x-axis
plt.ylabel("Frequency")      # Label for the y-axis
plt.title("Frequency of Alcohol Types")  # Title for the plot
# Out:
# Text(0.5, 1.0, 'Frequency of Alcohol Types')

# %%
sns.scatterplot(x = "Alcohol", y = "Malic acid", hue= 'Class', data = df)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %%
i=1
plt.figure(figsize=(20,20))
for feature in df:
    if feature!='Class' and feature!='Alcohol':
        plt.subplot(4,3,i)
        sns.scatterplot(x=df[feature], y=df['Alcohol'], hue=df['Class'])
        plt.grid()
        i+=1

# %% [markdown]
# # **Inferences:**
#
# **1.Affect of 'Malic Acid' on Alcohol:**
#
# ---
#
#
#
# Class 1: Less 'malic acid' leads to more Alcohol
#
# Class 2: Less 'malic acid' leads to less alcohol
#
# Class 3:Since Data points are scattered , no inference can be generated.
#
#
# **2.Affect of 'Ash' on Alcohol:**
#
# ---
#
#
#
# Class 1:High  'Ash' leads to more Alcohol and   alcohol is usually above 12.5 most of the times
#
# Class 2: For any 'Ash' levels, alcohol is usually under 13.0 most of the times
#
# Class 3:  High level of ash and High level of alcohol
#
#
# **3.Affect of 'Alcalinity of Ash' on Alcohol:**
#
# ---
#
#
#
# Class 1: For low levels of 'Alcalinity of Ash', alcohol levels are very high, almost always above 13.
#
# Class 2: For any 'Alcalinity of Ash' levels, alcohol is mostly  under 13.0.
#
# Class 3: No inference can be made.
#
#
#
# **4.Affect of 'Magnesium' on Alcohol:**
#
# ---
#
#
#
# Class 1: For 'Magnesium' levels of 90-120(moderate), alcohol levels are very high, almost above 13.
#
# Class 2: Alcohol levels are always under 13 and 'Magnesium' level is low.
#
# Class 3: Alcohol levels are between 12 and 14.
#
#
# **5.Affect of 'Total phenols' on Alcohol:**
#
# ---
#
#
#
# Class 1: High levels of 'Total phenols' will lead to high levels of alcohol.
#
# Class 2: Alcohol levels are always under 13 (less), no matter what 'Total phenols' levels are.
#
# Class 3: For low levels of 'Total phenols' itself, alcohol levels are high
#
#
# **6.Affect of 'Flavanoids' on Alcohol:**
#
# ---
#
#
#
# Class 1: For 'Flavanoids' levels of moderate level (range of 2-4), alcohol levels are very high.
#
# Class 2: For 'Flavanoids' levels of less(range of 1-3), alcohol levels are less, almost always below 13.
#
# Class 3: For low 'Flavanoids' levels, alcohol levels are moderate to high.
#
# **7.Affect of 'Non Flavanoid phenols' on Alcohol:**
#
# ---
#
#
#
# Class 1: For any range of 'Non Flavanoid phenols', Alcohol levels are usually always above 13(moderate to high).
#
# Class 2: For any range of 'Non Flavanoid phenols', Alcohol levels are mostly below 13(low).
#
# Class 3: No inference can be made.
#
#
# **8.Affect of 'Proanthocyanins' on Alcohol:**
#
# ---
#
#
#
# Class 1: For low  'Proanthocyanins' levels of 1.5-2.5, alcohol levels are usually very high (above range 13).
#
# Class 2: For any range of 'Proanthocyanins', Alcohol levels are moderate to low (mostly below 13).
#
# Class 3: For low 'Proanthocyanins' levels of 0.5-1.5, alcohol levels are usually moderate ( in the range 12-14)
#
#
# **9.Affect of 'Color intensity' on Alcohol:**
#
# ---
#
#
#
# Class 1: For 'Color intensity' moderate (between the levels of 4-8), alcohol levels are high.
#
# Class 2: For lower levels of 'Color intensity', alcohol levels are low.
#
# Class 3: No inference can be made.
#
#
# **10.Affect of 'Hue' on Alcohol:**
#
# ---
#
#
#
# Class 1: For moderate 'Hue' (range from of 0.8-1.2), alcohol levels are high(mostly above 13).
#
# Class 2: Alcohol levels are low (range under under 13) for any range of 'Hue'.
#
# Class 3: Lower Hue level range is widely spread along alcohol levels.
#
# **11.Affect of 'OD280/OD315 of diluted wines' on Alcohol:**
#
# ---
#
#
#
# Class 1: Starting from 'diluted wines' of level 2.5, alcohol levels are rising and high.
#
# Class 2: For any range, alcohol levels are low and under 13.
#
# Class 3: Lower  'OD280/OD315 of diluted wines' and higher alcohol range.
#
#
# **12.Affect of 'Proline' on Alcohol:**
#
# ---
#
#
#
#
#
# Class 1: As 'Proline' levels increase, Alcohol levels also increase.
#
# Class 2: For low levels of 'Proline', Alcohol levels are also low.
#
# Class 3: Lower Proline levels moderate alcohol level.
